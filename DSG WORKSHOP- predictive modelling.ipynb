# %%
import mumpy as np #For array processing, Linear Algebra
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-eef79a7a4228> in <module>()
# ----> 1 import mumpy as np #For array processing, Linear Algebra
#
# ImportError: No module named mumpy

# %%
import numpy as np #For array processing, Linear Algebra 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline #to open graphs in the notebook itself
# Out:
# UsageError: unrecognized arguments: #to open graphs in the notebook itself

# %%
# %matplotlib inline

# %%
data=pd.read_csv("Downloads/train_data.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-7a924ef31a32> in <module>()
# ----> 1 data=pd.read_csv("Downloads/train_data.csv")
#
# ...

# %%
data=pd.read_csv("anurag//Downloads//train_data.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-82deec7b11b5> in <module>()
# ----> 1 data=pd.read_csv("anurag//Downloads//train_data.csv")
#       2
#       3
#
# ...

# %%
data=pd.read_csv("anurag\\Downloads\\train_data.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-1cbb4530d522> in <module>()
# ----> 1 data=pd.read_csv("anurag\\Downloads\\train_data.csv")
#
# ...

# %%
data=pd.read_csv("/Users/anurag/Downloads/test_data.csv")

# %%
data.head()
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   50  Self-emp-not-inc   30731     Assoc-voc               11
# 1   38           Private  299810       HS-grad                9
# 2   23           Private  129767  Some-college               10
# 3   39       Federal-gov  257175     Bachelors               13
# 4   45           Private  174426       Masters               14
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married      Other-service  Not-in-family  White    Male
# 1  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 2       Never-married       Adm-clerical  Not-in-family  White  Female
# 3            Divorced       Tech-support      Unmarried  Black  Female
# 4  Married-civ-spouse     Prof-specialty        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0             0             0              50  United-States
# ...

# %%
data
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 0      50  Self-emp-not-inc   30731     Assoc-voc               11
# 1      38           Private  299810       HS-grad                9
# 2      23           Private  129767  Some-college               10
# 3      39       Federal-gov  257175     Bachelors               13
# 4      45           Private  174426       Masters               14
# 5      63  Self-emp-not-inc  344128     Bachelors               13
# 6      41           Private   34278     Assoc-voc               11
# 7      32           Private  105749   Prof-school               15
# 8      40           Private  237601     Bachelors               13
# 9      24       Federal-gov  219519  Some-college               10
# 10     32           Private  131584       HS-grad                9
# 11     40           Private  190044    Assoc-acdm               12
# 12     21           Private  218957          11th                7
# ...

# %%
data=pd.read_csv("/Users/anurag/Downloads/train_data.csv")

# %%
data
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       49           Private  246183       HS-grad                9
# 1       57           Private  176904          11th                7
# 2       50           Private  421561  Some-college               10
# 3       24           Private   29810  Some-college               10
# 4       21           Private   77572       HS-grad                9
# 5       38           Private   97083  Some-college               10
# 6       59         Local-gov   75785          11th                7
# 7       52           Private  156953       HS-grad                9
# 8       41           Private  190885       HS-grad                9
# 9       38           Private  272476     Bachelors               13
# 10      24           Private  183594       HS-grad                9
# 11      17         Local-gov  292285          11th                7
# 12      54         Local-gov  116428          10th                6
# ...

# %%
test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-00234e7d8d72> in <module>()
# ----> 1 test_data
#
# NameError: name 'test_data' is not defined

# %%
test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-00234e7d8d72> in <module>()
# ----> 1 test_data
#
# NameError: name 'test_data' is not defined

# %%
test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-00234e7d8d72> in <module>()
# ----> 1 test_data
#
# NameError: name 'test_data' is not defined

# %%
data=pd.read_csv("/Users/anurag/Downloads/test_data.csv")

# %%
test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-00234e7d8d72> in <module>()
# ----> 1 test_data
#
# NameError: name 'test_data' is not defined

# %%
test_data =pd.read_csv("/Users/anurag/Downloads/test_data.csv")

# %%
test_data
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 0      50  Self-emp-not-inc   30731     Assoc-voc               11
# 1      38           Private  299810       HS-grad                9
# 2      23           Private  129767  Some-college               10
# 3      39       Federal-gov  257175     Bachelors               13
# 4      45           Private  174426       Masters               14
# 5      63  Self-emp-not-inc  344128     Bachelors               13
# 6      41           Private   34278     Assoc-voc               11
# 7      32           Private  105749   Prof-school               15
# 8      40           Private  237601     Bachelors               13
# 9      24       Federal-gov  219519  Some-college               10
# 10     32           Private  131584       HS-grad                9
# 11     40           Private  190044    Assoc-acdm               12
# 12     21           Private  218957          11th                7
# ...

# %%
data=pd.read_csv("/Users/anurag/Downloads/train_data.csv")

# %%
len(data)
# Out:
# 36177

# %%
data.age.head()
# Out:
# 0    49
# 1    57
# 2    50
# 3    24
# 4    21
# Name: age, dtype: int64

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  educational-num      marital-status  \
# 0   49   Private  246183       HS-grad                9  Married-civ-spouse
# 1   57   Private  176904          11th                7  Married-civ-spouse
# 2   50   Private  421561  Some-college               10            Divorced
# 3   24   Private   29810  Some-college               10       Never-married
# 4   21   Private   77572       HS-grad                9       Never-married
#
#           occupation   relationship                race  gender  capital-gain  \
# 0              Sales        Husband               White    Male             0
# 1  Handlers-cleaners        Husband               White    Male             0
# 2    Exec-managerial  Not-in-family               White    Male             0
# 3     Prof-specialty      Own-child               White  Female             0
# 4  Handlers-cleaners  Not-in-family  Asian-Pac-Islander  Female             0
#
# ...

# %%
data[["age", "education"]].head()
# Out:
#    age     education
# 0   49       HS-grad
# 1   57          11th
# 2   50  Some-college
# 3   24  Some-college
# 4   21       HS-grad

# %%
data["age", "education"].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e77cce078b97> in <module>()
# ----> 1 data["age", "education"].head()
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
data[["age", "education"]].head()
# Out:
#    age     education
# 0   49       HS-grad
# 1   57          11th
# 2   50  Some-college
# 3   24  Some-college
# 4   21       HS-grad

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
categorical_variable=data.dtypes[data.dtype=='object'].indexvalues
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-1980ab168146> in <module>()
# ----> 1 categorical_variable=data.dtypes[data.dtype=='object'].indexvalues
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
categorical_variable=data.dtypes[data.dtype=='object'].index.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-95c484557431> in <module>()
# ----> 1 categorical_variable=data.dtypes[data.dtype=='object'].index.values
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
categorical_variable=data.dtypes[data.dtypes=='object'].index.values

# %%
categorical_variable
# Out:
# array(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'gender', 'native-country', 'income'], dtype=object)

# %%
data.hist('age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f75d8d0>]], dtype=object)

# %%
data.boxplot('age')

# %%
I have a plan for you
# Out:
#   File "<ipython-input-33-cfd4e082f479>", line 1
#     I have a plan for you
#          ^
# SyntaxError: invalid syntax

# %%
data.hist('gender')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-4c6c9f176aaa> in <module>()
# ----> 1 data.hist('gender')
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2123     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2124                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2125                           layout=layout)
#    2126     _axes = _flatten(axes)
#    2127
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/plotting/_tools.pyc in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     236
#     237     # Create first subplot separately, so we can share it if requested
# ...

# %%
data.hist('education')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-a84d95b6d942> in <module>()
# ----> 1 data.hist('education')
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/plotting/_core.pyc in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2123     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2124                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2125                           layout=layout)
#    2126     _axes = _flatten(axes)
#    2127
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/plotting/_tools.pyc in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     236
#     237     # Create first subplot separately, so we can share it if requested
# ...

# %%
data.[categorical_variable].apply(lambda x: len(x.unique()))
# Out:
#   File "<ipython-input-36-63bab5acd8d6>", line 1
#     data.[categorical_variable].apply(lambda x: len(x.unique()))
#          ^
# SyntaxError: invalid syntax

# %%
data[categorical_variable].apply(lambda x: len(x.unique()))
# Out:
# workclass          7
# education         16
# marital-status     7
# occupation        14
# relationship       6
# race               5
# gender             2
# native-country    41
# income             2
# dtype: int64

# %%
data.workclass.value_counts().plot(kind='bar')

# %%
data.native-country.value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-18b37a8b6136> in <module>()
# ----> 1 data.native-country.value_counts().plot(kind='bar')
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'native'

# %%
data.education.value_counts().plot(kind='bar')

# %%
data.workclass.value_counts().plot(kind='box')

# %%
data.corr()
# Out:
#                       age    fnlwgt  educational-num  capital-gain  \
# age              1.000000 -0.075749         0.038600      0.081606
# fnlwgt          -0.075749  1.000000        -0.043001     -0.004848
# educational-num  0.038600 -0.043001         1.000000      0.127566
# capital-gain     0.081606 -0.004848         0.127566      1.000000
# capital-loss     0.060332 -0.003348         0.085594     -0.032262
# hours-per-week   0.106150 -0.019472         0.147033      0.081636
#
#                  capital-loss  hours-per-week
# age                  0.060332        0.106150
# fnlwgt              -0.003348       -0.019472
# educational-num      0.085594        0.147033
# capital-gain        -0.032262        0.081636
# capital-loss         1.000000        0.052876
# hours-per-week       0.052876        1.000000

# %%
data.boxplot(column='age', by='gender')

# %%
crosstable=pd.crosstab(data.gender,data.income)
crosstable.plot(kind='bar',stacked=True)

# %%
crosstable=pd.crosstab(data.gender,data.income)
crosstable.plot(kind='bar',stacked=False)

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  educational-num      marital-status  \
# 0   49   Private  246183       HS-grad                9  Married-civ-spouse
# 1   57   Private  176904          11th                7  Married-civ-spouse
# 2   50   Private  421561  Some-college               10            Divorced
# 3   24   Private   29810  Some-college               10       Never-married
# 4   21   Private   77572       HS-grad                9       Never-married
#
#           occupation   relationship                race  gender  capital-gain  \
# 0              Sales        Husband               White    Male             0
# 1  Handlers-cleaners        Husband               White    Male             0
# 2    Exec-managerial  Not-in-family               White    Male             0
# 3     Prof-specialty      Own-child               White  Female             0
# 4  Handlers-cleaners  Not-in-family  Asian-Pac-Islander  Female             0
#
# ...

# %%
dependent_variable= 'income'
independent_variable= [ x for in data.columns if x not is [dependent_variable]]
# Out:
#   File "<ipython-input-47-14161aae1e81>", line 2
#     independent_variable= [ x for in data.columns if x not is [dependent_variable]]
#                                    ^
# SyntaxError: invalid syntax

# %%
dependent_variable= 'income'
independent_variable= [ x for x in data.columns if x not is [dependent_variable]]
# Out:
#   File "<ipython-input-48-d64ce5819c05>", line 2
#     independent_variable= [ x for x in data.columns if x not is [dependent_variable]]
#                                                               ^
# SyntaxError: invalid syntax

# %%
dependent_variable= 'income'
independent_variable= [ x for in (data.columns) if x not is [dependent_variable]]
# Out:
#   File "<ipython-input-49-16e64089c170>", line 2
#     independent_variable= [ x for in (data.columns) if x not is [dependent_variable]]
#                                    ^
# SyntaxError: invalid syntax

# %%
dependent_variable= 'income'
independent_variable= [ x for x in (data.columns) if x not is [dependent_variable]]
# Out:
#   File "<ipython-input-50-4a01a884cf52>", line 2
#     independent_variable= [ x for x in (data.columns) if x not is [dependent_variable]]
#                                                                 ^
# SyntaxError: invalid syntax

# %%
dependent_variable= 'income'
independent_variable= [ x for x in data.columns if x not in [dependent_variable]]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for var in categorical_variable:
    data[var]=le.fit_transform(data[var])

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0   49          2  246183         11                9               2
# 1   57          2  176904          1                7               2
# 2   50          2  421561         15               10               0
# 3   24          2   29810         15               10               4
# 4   21          2   77572         11                9               4
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0          11             0     4       1             0             0
# 1           5             0     4       1             0             0
# 2           3             1     4       1             0             0
# 3           9             3     4       0             0             0
# 4           5             1     1       0             0             0
#
#    hours-per-week  native-country  income
# 0              40              38       1
# ...

# %%
from sklearn.cross_validation import train_test_split
train, test = train_test_split(data, test_size=.2, stratify=data.income)
# Out:
# /Applications/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
print(len(data))
# Out:
# 36177

# %%
print(len(data))
print(len(train))
print(len(test))
# Out:
# 36177
# 28941
# 7236

# %%
train.income.value_counts()/len(train)
# Out:
# 0    0.752151
# 1    0.247849
# Name: income, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# %%
#creating our model
model1=LogisticRegression()

# %%
train.head()
# Out:
#        age  workclass  fnlwgt  education  educational-num  marital-status  \
# 30222   31          2  326104          9               13               2
# 17739   44          4   22933         11                9               2
# 28859   23          2   46645          9               13               4
# 24576   51          2  122533          9               13               2
# 2376    46          2  230806         15               10               4
#
#        occupation  relationship  race  gender  capital-gain  capital-loss  \
# 30222           4             0     4       1             0             0
# 17739           3             0     4       1             0             0
# 28859           9             1     4       0             0             0
# 24576           3             0     4       1             0             0
# 2376            3             1     4       0             0             0
#
#        hours-per-week  native-country  income
# ...

# %%
Independent_variables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-0c9356ac565b> in <module>()
# ----> 1 Independent_variables
#
# NameError: name 'Independent_variables' is not defined

# %%
independent_variable
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'educational-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'gender',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %%
#training our model
model1.fit(train[independent_variable], train[dependent_variable])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
prediction= model1.predict(test[independent_variable])

# %%
prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(prediction , test.income)
# Out:
# 0.79698728579325595

# %%
#importing decision tree algo
from sklearn.tree import DecisionTreeClassifier

# %%
model2=DecisionTreeClassifier()

# %%
model2.fit(train[independent_variable], train[dependent_variable])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
prediction = model2.predict(test[independent_variable])

# %%
prediction
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
accuracy_score(prediction, test[dependent_variable])
# Out:
# 0.81149806522940848

# %%
xubus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-31e1474a9651> in <module>()
# ----> 1 xubus
#
# NameError: name 'xubus' is not defined

# %%
lightgbm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-0942b01db991> in <module>()
# ----> 1 lightgbm
#
# NameError: name 'lightgbm' is not defined
